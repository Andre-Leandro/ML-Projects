# %%
import pandas as pd

# %%
train = pd.read_csv('dataset/train.csv')
train.head()
# Out:
#     candidate_id     query_id snapshot_date  seller_id region  \
# 0  cand_00000000  qry_0000000    2024-01-08  sel_00000   west
# 1  cand_00000001  qry_0000000    2024-01-08  sel_00000   west
# 2  cand_00000002  qry_0000000    2024-01-08  sel_00000   west
# 3  cand_00000003  qry_0000000    2024-01-08  sel_00000   west
# 4  cand_00000004  qry_0000000    2024-01-08  sel_00000   west
#
#   primary_category seller_tier  week_of_year  month  quarter  ...  \
# 0          apparel      growth             2      1        1  ...
# 1          apparel      growth             2      1        1  ...
# 2          apparel      growth             2      1        1  ...
# 3          apparel      growth             2      1        1  ...
# 4          apparel      growth             2      1        1  ...
#
#    visibility_boost  inventory_synergy  loyalty_synergy  margin_penalty  \
# 0              0.10               0.40             0.10            0.35
# ...

# %%
test = pd.read_csv('dataset/test.csv')
test.head()
# Out:
#     candidate_id     query_id snapshot_date  seller_id region  \
# 0  cand_00211200  qry_0026400    2024-06-10  sel_00000   west
# 1  cand_00211201  qry_0026400    2024-06-10  sel_00000   west
# 2  cand_00211202  qry_0026400    2024-06-10  sel_00000   west
# 3  cand_00211203  qry_0026400    2024-06-10  sel_00000   west
# 4  cand_00211204  qry_0026400    2024-06-10  sel_00000   west
#
#   primary_category seller_tier  week_of_year  month  quarter  ...  \
# 0          apparel      growth            24      6        2  ...
# 1          apparel      growth            24      6        2  ...
# 2          apparel      growth            24      6        2  ...
# 3          apparel      growth            24      6        2  ...
# 4          apparel      growth            24      6        2  ...
#
#    discount_depth  visibility_boost  inventory_synergy  loyalty_synergy  \
# 0            0.18              0.10               0.40             0.10
# ...

# %%
train.promo_tool.value_counts()
# Out:
# promo_tool
# coupon_pack                  26400
# free_shipping_boost          26400
# cashback_offer               26400
# bundle_builder               26400
# flash_sale_slot              26400
# homepage_feature             26400
# sponsored_search_boost       26400
# loyalty_points_multiplier    26400
# Name: count, dtype: int64

# %%
train.tool_type.nunique()
# Out:
# 6

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211200 entries, 0 to 211199
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   candidate_id               211200 non-null  object
#  1   query_id                   211200 non-null  object
#  2   snapshot_date              211200 non-null  object
#  3   seller_id                  211200 non-null  object
#  4   region                     211200 non-null  object
#  5   primary_category           211200 non-null  object
#  6   seller_tier                211200 non-null  object
#  7   week_of_year               211200 non-null  int64
#  8   month                      211200 non-null  int64
#  9   quarter                    211200 non-null  int64
#  10  seller_tenure_days         211200 non-null  int64
#  11  orders_30d                 211200 non-null  int64
#  12  gmv_30d                    211200 non-null  float64
# ...
